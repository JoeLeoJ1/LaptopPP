# %% [markdown]
# # **Assignment**
# Your task is to define and train a machine learning model for predicting the price of a laptop (buynow_price column in the dataset) based on its attributes. When testing and comparing your models, aim to minimize the RMSE measure.

# %% [markdown]
# # **Data Exploration and Processing**

# %%
import pandas as pd
import os
import numpy as np

# %%
# read datasets as intsructed
train_df = pd.read_json("/content/train_dataset.json", orient="columns")
test_df = pd.read_json("/content/test_dataset.json", orient="columns")
val_df = pd.read_json("/content/val_dataset.json", orient="columns")

df = pd.concat([train_df, val_df, test_df], axis=0)
df.head(10)
# Out:
#          graphic card type                                     communications  \
# 7233    dedicated graphics                  [bluetooth, lan 10/100/1000 mbps]
# 5845    dedicated graphics                [wi-fi, bluetooth, lan 10/100 mbps]
# 10303                 None        [bluetooth, nfc (near field communication)]
# 10423                 None                                               None
# 5897   integrated graphics                                 [wi-fi, bluetooth]
# 4870   integrated graphics                [wi-fi, bluetooth, lan 10/100 mbps]
# 2498    dedicated graphics           [wi-fi, bluetooth, lan 10/100/1000 mbps]
# 6220    dedicated graphics           [wi-fi, bluetooth, lan 10/100/1000 mbps]
# 10594  integrated graphics              [nfc (near field communication), gps]
# 11640  integrated graphics  [wi-fi 802.11 b/g/n/ac, bluetooth, lan 10/100/...
#
#       resolution (px) CPU cores RAM size                  operating system  \
# 7233      1920 x 1080         4    32 gb                       [no system]
# 5845       1366 x 768         4     8 gb                 [windows 10 home]
# 10303     1920 x 1080         2     8 gb                 [windows 10 home]
# 10423            None         2     None                              None
# 5897      2560 x 1440         4     8 gb                 [windows 10 home]
# 4870       1366 x 768         2     8 gb                 [windows 10 home]
# 2498      1920 x 1080         4     8 gb  [windows 8.1 home 64-bit, other]
# 6220      1920 x 1080         4     8 gb                       [no system]
# 10594     1920 x 1080         2     8 gb         [windows 10 professional]
# 11640     1920 x 1080         2     8 gb         [windows 10 professional]
#
#       drive type                                      input devices  \
# 7233   ssd + hdd  [keyboard, touchpad, illuminated keyboard, num...
# 5845         ssd             [keyboard, touchpad, numeric keyboard]
# 10303        hdd                                               None
# 10423       None                                               None
# 5897         ssd         [keyboard, touchpad, illuminated keyboard]
# 4870         hdd             [keyboard, touchpad, numeric keyboard]
# 2498         hdd  [keyboard, touchpad, illuminated keyboard, num...
# 6220         ssd  [keyboard, touchpad, illuminated keyboard, num...
# 10594       None                                         [touchpad]
# 11640        ssd             [keyboard, touchpad, numeric keyboard]
#
#                                            multimedia RAM type  \
# 7233   [SD card reader, camera, speakers, microphone]     ddr4
# 5845   [SD card reader, camera, speakers, microphone]     ddr3
# 10303                                [SD card reader]     ddr4
# 10423                                            None     None
# 5897   [SD card reader, camera, speakers, microphone]     ddr4
# 4870   [SD card reader, camera, speakers, microphone]     ddr4
# 2498   [SD card reader, camera, speakers, microphone]     ddr3
# 6220   [SD card reader, camera, speakers, microphone]     ddr4
# 10594                                [SD card reader]     ddr4
# 11640  [SD card reader, camera, speakers, microphone]     ddr4
#
#        CPU clock speed (GHz)      CPU model state  drive memory size (GB)  \
# 7233                     2.6  intel core i7   new                  1250.0
# 5845                     2.4  intel core i7   new                   256.0
# 10303                    1.6  intel core i7   new                  1000.0
# 10423                    NaN           None   new                     NaN
# 5897                     1.2      other CPU   new                   256.0
# 4870                     2.0  intel core i3   new                  1000.0
# 2498                     2.4  intel core i7   new                  1000.0
# 6220                     2.5  intel core i5   new                   256.0
# 10594                    2.5  intel core i5   new                   500.0
# 11640                    2.5  intel core i5   new                   256.0
#
#                 warranty  screen size  buynow_price
# 7233   producer warranty  17" - 17.9"        4999.0
# 5845     seller warranty  15" - 15.9"        2649.0
# 10303  producer warranty  15" - 15.9"        3399.0
# 10423  producer warranty         None        1599.0
# 5897   producer warranty  12" - 12.9"        4499.0
# 4870   producer warranty  15" - 15.9"        2099.0
# 2498   producer warranty  17" - 17.9"        2699.0
# 6220   producer warranty  15" - 15.9"        3199.0
# 10594  producer warranty  15" - 15.9"        2749.0
# 11640  producer warranty  15" - 15.9"        3199.0

# %%
df.dtypes
# Out:
# graphic card type          object
# communications             object
# resolution (px)            object
# CPU cores                  object
# RAM size                   object
# operating system           object
# drive type                 object
# input devices              object
# multimedia                 object
# RAM type                   object
# CPU clock speed (GHz)     float64
# CPU model                  object
# state                      object
# drive memory size (GB)    float64
# warranty                   object
# screen size                object
# buynow_price              float64
# dtype: object

# %%
df.shape
# Out:
# (7853, 17)

# %%
# Look at unique values of each column, except the ones formatted as list
for col in df.columns.to_list():
    if type(df[col][0]) != list:
        print(f"unique values of {col} are: ", df[col].unique())
        print("-----------------------------------------------------")
# Out:
# unique values of graphic card type are:  ['dedicated graphics' None 'integrated graphics']
# -----------------------------------------------------
# unique values of resolution (px) are:  ['1920 x 1080' '1366 x 768' None '2560 x 1440' '1600 x 900' '3840 x 2160'
#  'other' '1920 x 1280' '1280 x 800' '3200 x 1800' '2880 x 1620'
#  '2160 x 1440' '1920 x 1200' '2560 x 1600']
# -----------------------------------------------------
# unique values of CPU cores are:  ['4' '2' 'not applicable' '3' '1' '8' '6']
# -----------------------------------------------------
# unique values of RAM size are:  ['32 gb' '8 gb' None '12 gb' '4 gb' '16 gb' '2 gb' '20 gb' '6 gb' '64 gb'
#  '256 mb' '24 gb']
# -----------------------------------------------------
# unique values of drive type are:  ['ssd + hdd' 'ssd' 'hdd' None 'emmc' 'hybrid']
# -----------------------------------------------------
# unique values of RAM type are:  ['ddr4' 'ddr3' None 'ddr3l']
# -----------------------------------------------------
# unique values of CPU clock speed (GHz) are:  [2.6  2.4  1.6   nan 1.2  2.   2.5  2.8  1.9  1.1  2.3  2.24 1.8  3.
#  1.7  2.1  2.7  1.33 2.2  3.9  2.16 2.9  1.83 0.9  1.   1.44 1.58 1.35
#  3.1  0.8  3.5  1.3  1.5  1.86 3.3  1.15 1.68 1.4  2.66 2.13 1.66 1.46
#  2.56 3.8  3.6  0.  ]
# -----------------------------------------------------
# unique values of CPU model are:  ['intel core i7' None 'other CPU' 'intel core i3' 'intel core i5'
#  'intel celeron dual-core' 'intel pentium 4' 'intel celeron quad core '
#  'amd a6' 'intel celeron ' 'intel pentium dual-core' 'amd a12' 'amd a8'
#  'intel pentium quad-core ' 'intel core m' 'amd a4' 'intel celeron m'
#  'amd a10' 'amd e1']
# -----------------------------------------------------
# unique values of state are:  ['new']
# -----------------------------------------------------
# unique values of drive memory size (GB) are:  [1.250e+03 2.560e+02 1.000e+03       nan 5.000e+02 1.128e+03 1.240e+03
#  1.200e+02 1.256e+03 4.800e+02 2.500e+02 1.280e+02 2.400e+02 3.200e+01
#  9.600e+02 6.400e+01 1.000e+00 1.120e+03 2.128e+03 6.800e+01 5.120e+02
#  1.512e+03 1.500e+03 2.000e+03 1.628e+03 2.256e+03 1.800e+02 2.512e+03
#  1.024e+03 2.500e+03 1.756e+03 6.280e+02 5.080e+02 1.520e+02 3.200e+02
#  1.012e+03 7.560e+02 1.600e+02 2.480e+03 4.880e+02 8.000e+00 2.048e+03
#  0.000e+00 1.000e+02 1.008e+03 9.900e+02 2.120e+03 2.480e+02 7.500e+02
#  6.080e+02 4.960e+02 2.960e+03 1.920e+02 1.525e+03 3.680e+02 3.840e+02
#  7.400e+02 5.250e+02 1.480e+03 5.160e+02 3.640e+02 2.720e+02 1.280e+03
#  1.728e+03 1.726e+03 5.240e+02 7.680e+02 2.250e+03 1.000e+04 6.000e+01
#  1.275e+03 2.750e+02 9.800e+02]
# -----------------------------------------------------
# unique values of warranty are:  ['producer warranty' 'seller warranty' 'no warranty']
# -----------------------------------------------------
# unique values of screen size are:  ['17" - 17.9"' '15" - 15.9"' None '12" - 12.9"' '14" - 14.9"'
#  '13" - 13.9"' '11.9" and less']
# -----------------------------------------------------
# unique values of buynow_price are:  [4999.   2649.   3399.   ... 2925.36 8678.   4722.  ]
# -----------------------------------------------------

# %%
#  state only takes one value
# drop this column since it won't effect the price
df = df.drop(columns=['state'])
df = df.dropna()

# %%
# columns of communications, input_devices and multimedia include multiple values in a cell in list format
# not possible to represent them in numerics in its current format
# split the values of these columns into different columns
compact_cols = ['communications', 'input devices', 'multimedia']

# %%
# use to_list( ) function to split lists into columns
# example of to_list( ) function of pandas
pd.DataFrame(df['communications'].to_list())
# Out:
#               0                     1                     2     3     4     5
# 0     bluetooth  lan 10/100/1000 mbps                  None  None  None  None
# 1         wi-fi             bluetooth       lan 10/100 mbps  None  None  None
# 2         wi-fi             bluetooth                  None  None  None  None
# 3         wi-fi             bluetooth       lan 10/100 mbps  None  None  None
# 4         wi-fi             bluetooth  lan 10/100/1000 mbps  None  None  None
# ...         ...                   ...                   ...   ...   ...   ...
# 6104      wi-fi             bluetooth  lan 10/100/1000 mbps  None  None  None
# 6105  bluetooth       lan 10/100 mbps                  None  None  None  None
# 6106      wi-fi             bluetooth  lan 10/100/1000 mbps  None  None  None
# 6107  bluetooth       lan 10/100 mbps                  None  None  None  None
# 6108  bluetooth       lan 10/100 mbps                  None  None  None  None
#
# [6109 rows x 6 columns]

# %%
# get unique values of each features in our predefined lists
# and convert them to new feature names

def get_unique_vals(col_name):
    #to_list function splits each comma separated value to a new column
    col_df = pd.DataFrame(df[col_name].to_list())
    unique_vals = list()
    for col in col_df.columns.to_list():
        unique_vals += [val for val in list(col_df[col].unique()) if (val not in unique_vals and val is not None) ]

    return unique_vals

# %%
compact_dict = {col: [] for  col in compact_cols}

# apply get_unique_vals to all compact_cols
# search through the dataframe and add a feature to unique_vals list when it is not included before
for col in compact_cols:
    compact_dict[col] = get_unique_vals(col)

# %%
compact_dict
# Out:
# {'communications': ['bluetooth',
#   'wi-fi',
#   'wi-fi 802.11 b/g/n/ac',
#   'lan 10/100 mbps',
#   'wi-fi 802.11 a/b/g/n/ac',
#   'nfc (near field communication)',
#   'lan 10/100/1000 mbps',
#   'gps',
#   'wi-fi 802.11 b/g/n',
#   'intel wireless display (widi)',
#   'wi-fi 802.11 a/b/g/n',
#   'modem 3g (wwan)',
#   'modem 4g (lte)'],
#  'input devices': ['keyboard',
#   'touchpad',
#   'illuminated keyboard',
#   'numeric keyboard'],
#  'multimedia': ['SD card reader', 'camera', 'microphone', 'speakers']}

# %%
# transform string value to integer by excluding gb and mb
df['RAM size'] = df['RAM size'].str.replace(' gb','',regex=True)

# when regex=False, replace requires exact match
df['RAM size'] = df['RAM size'].str.replace('256 mb','0.256',regex=False)
df
# Out:
#         graphic card type                            communications  \
# 7233   dedicated graphics         [bluetooth, lan 10/100/1000 mbps]
# 5845   dedicated graphics       [wi-fi, bluetooth, lan 10/100 mbps]
# 5897  integrated graphics                        [wi-fi, bluetooth]
# 4870  integrated graphics       [wi-fi, bluetooth, lan 10/100 mbps]
# 2498   dedicated graphics  [wi-fi, bluetooth, lan 10/100/1000 mbps]
# ...                   ...                                       ...
# 9211   dedicated graphics  [wi-fi, bluetooth, lan 10/100/1000 mbps]
# 2748   dedicated graphics              [bluetooth, lan 10/100 mbps]
# 2072   dedicated graphics  [wi-fi, bluetooth, lan 10/100/1000 mbps]
# 4741   dedicated graphics              [bluetooth, lan 10/100 mbps]
# 6980   dedicated graphics              [bluetooth, lan 10/100 mbps]
#
#      resolution (px) CPU cores RAM size                  operating system  \
# 7233     1920 x 1080         4       32                       [no system]
# 5845      1366 x 768         4        8                 [windows 10 home]
# 5897     2560 x 1440         4        8                 [windows 10 home]
# 4870      1366 x 768         2        8                 [windows 10 home]
# 2498     1920 x 1080         4        8  [windows 8.1 home 64-bit, other]
# ...              ...       ...      ...                               ...
# 9211     1920 x 1080         4       32                 [windows 10 home]
# 2748      1600 x 900         4        8                 [windows 10 home]
# 2072     1920 x 1080         4        8                       [no system]
# 4741     1920 x 1080         4       12                       [no system]
# 6980     1920 x 1080         4       32                 [windows 10 home]
#
#      drive type                                      input devices  \
# 7233  ssd + hdd  [keyboard, touchpad, illuminated keyboard, num...
# 5845        ssd             [keyboard, touchpad, numeric keyboard]
# 5897        ssd         [keyboard, touchpad, illuminated keyboard]
# 4870        hdd             [keyboard, touchpad, numeric keyboard]
# 2498        hdd  [keyboard, touchpad, illuminated keyboard, num...
# ...         ...                                                ...
# 9211        ssd  [keyboard, touchpad, illuminated keyboard, num...
# 2748        hdd             [keyboard, touchpad, numeric keyboard]
# 2072  ssd + hdd  [keyboard, touchpad, illuminated keyboard, num...
# 4741  ssd + hdd         [keyboard, touchpad, illuminated keyboard]
# 6980        ssd         [keyboard, touchpad, illuminated keyboard]
#
#                                           multimedia RAM type  \
# 7233  [SD card reader, camera, speakers, microphone]     ddr4
# 5845  [SD card reader, camera, speakers, microphone]     ddr3
# 5897  [SD card reader, camera, speakers, microphone]     ddr4
# 4870  [SD card reader, camera, speakers, microphone]     ddr4
# 2498  [SD card reader, camera, speakers, microphone]     ddr3
# ...                                              ...      ...
# 9211  [SD card reader, camera, speakers, microphone]     ddr4
# 2748  [SD card reader, camera, speakers, microphone]     ddr3
# 2072  [SD card reader, camera, speakers, microphone]     ddr4
# 4741  [SD card reader, camera, speakers, microphone]     ddr4
# 6980                  [camera, speakers, microphone]     ddr4
#
#       CPU clock speed (GHz)      CPU model  drive memory size (GB)  \
# 7233                    2.6  intel core i7                  1250.0
# 5845                    2.4  intel core i7                   256.0
# 5897                    1.2      other CPU                   256.0
# 4870                    2.0  intel core i3                  1000.0
# 2498                    2.4  intel core i7                  1000.0
# ...                     ...            ...                     ...
# 9211                    2.8  intel core i7                   500.0
# 2748                    2.2  intel core i7                  1000.0
# 2072                    2.6  intel core i7                  1120.0
# 4741                    2.8  intel core i7                  1256.0
# 6980                    2.8  intel core i7                   240.0
#
#                warranty  screen size  buynow_price
# 7233  producer warranty  17" - 17.9"       4999.00
# 5845    seller warranty  15" - 15.9"       2649.00
# 5897  producer warranty  12" - 12.9"       4499.00
# 4870  producer warranty  15" - 15.9"       2099.00
# 2498  producer warranty  17" - 17.9"       2699.00
# ...                 ...          ...           ...
# 9211  producer warranty  15" - 15.9"       5599.00
# 2748    seller warranty  17" - 17.9"       2925.36
# 2072  producer warranty  17" - 17.9"       3799.00
# 4741  producer warranty  15" - 15.9"       5589.00
# 6980  producer warranty  15" - 15.9"       8678.00
#
# [6109 rows x 16 columns]

# %%
# screen size column is given as intervals.
# convert it as integers such as so 11.9" and less would become 11
df['screen size'] = df['screen size'].apply(lambda x: int(str(x)[:2]))
df
# Out:
#         graphic card type                            communications  \
# 7233   dedicated graphics         [bluetooth, lan 10/100/1000 mbps]
# 5845   dedicated graphics       [wi-fi, bluetooth, lan 10/100 mbps]
# 5897  integrated graphics                        [wi-fi, bluetooth]
# 4870  integrated graphics       [wi-fi, bluetooth, lan 10/100 mbps]
# 2498   dedicated graphics  [wi-fi, bluetooth, lan 10/100/1000 mbps]
# ...                   ...                                       ...
# 9211   dedicated graphics  [wi-fi, bluetooth, lan 10/100/1000 mbps]
# 2748   dedicated graphics              [bluetooth, lan 10/100 mbps]
# 2072   dedicated graphics  [wi-fi, bluetooth, lan 10/100/1000 mbps]
# 4741   dedicated graphics              [bluetooth, lan 10/100 mbps]
# 6980   dedicated graphics              [bluetooth, lan 10/100 mbps]
#
#      resolution (px) CPU cores RAM size                  operating system  \
# 7233     1920 x 1080         4       32                       [no system]
# 5845      1366 x 768         4        8                 [windows 10 home]
# 5897     2560 x 1440         4        8                 [windows 10 home]
# 4870      1366 x 768         2        8                 [windows 10 home]
# 2498     1920 x 1080         4        8  [windows 8.1 home 64-bit, other]
# ...              ...       ...      ...                               ...
# 9211     1920 x 1080         4       32                 [windows 10 home]
# 2748      1600 x 900         4        8                 [windows 10 home]
# 2072     1920 x 1080         4        8                       [no system]
# 4741     1920 x 1080         4       12                       [no system]
# 6980     1920 x 1080         4       32                 [windows 10 home]
#
#      drive type                                      input devices  \
# 7233  ssd + hdd  [keyboard, touchpad, illuminated keyboard, num...
# 5845        ssd             [keyboard, touchpad, numeric keyboard]
# 5897        ssd         [keyboard, touchpad, illuminated keyboard]
# 4870        hdd             [keyboard, touchpad, numeric keyboard]
# 2498        hdd  [keyboard, touchpad, illuminated keyboard, num...
# ...         ...                                                ...
# 9211        ssd  [keyboard, touchpad, illuminated keyboard, num...
# 2748        hdd             [keyboard, touchpad, numeric keyboard]
# 2072  ssd + hdd  [keyboard, touchpad, illuminated keyboard, num...
# 4741  ssd + hdd         [keyboard, touchpad, illuminated keyboard]
# 6980        ssd         [keyboard, touchpad, illuminated keyboard]
#
#                                           multimedia RAM type  \
# 7233  [SD card reader, camera, speakers, microphone]     ddr4
# 5845  [SD card reader, camera, speakers, microphone]     ddr3
# 5897  [SD card reader, camera, speakers, microphone]     ddr4
# 4870  [SD card reader, camera, speakers, microphone]     ddr4
# 2498  [SD card reader, camera, speakers, microphone]     ddr3
# ...                                              ...      ...
# 9211  [SD card reader, camera, speakers, microphone]     ddr4
# 2748  [SD card reader, camera, speakers, microphone]     ddr3
# 2072  [SD card reader, camera, speakers, microphone]     ddr4
# 4741  [SD card reader, camera, speakers, microphone]     ddr4
# 6980                  [camera, speakers, microphone]     ddr4
#
#       CPU clock speed (GHz)      CPU model  drive memory size (GB)  \
# 7233                    2.6  intel core i7                  1250.0
# 5845                    2.4  intel core i7                   256.0
# 5897                    1.2      other CPU                   256.0
# 4870                    2.0  intel core i3                  1000.0
# 2498                    2.4  intel core i7                  1000.0
# ...                     ...            ...                     ...
# 9211                    2.8  intel core i7                   500.0
# 2748                    2.2  intel core i7                  1000.0
# 2072                    2.6  intel core i7                  1120.0
# 4741                    2.8  intel core i7                  1256.0
# 6980                    2.8  intel core i7                   240.0
#
#                warranty  screen size  buynow_price
# 7233  producer warranty           17       4999.00
# 5845    seller warranty           15       2649.00
# 5897  producer warranty           12       4499.00
# 4870  producer warranty           15       2099.00
# 2498  producer warranty           17       2699.00
# ...                 ...          ...           ...
# 9211  producer warranty           15       5599.00
# 2748    seller warranty           17       2925.36
# 2072  producer warranty           17       3799.00
# 4741  producer warranty           15       5589.00
# 6980  producer warranty           15       8678.00
#
# [6109 rows x 16 columns]

# %%
# split resolution (px) column into two columns of integers (resolution_x and resolution_y)
# as 1280 x 800 would have 1280 in the first column and 800 in the second column
df['resolution_x'] = df['resolution (px)'].apply(lambda x: x.split(' x ')[0]).astype(int)
df['resolution_y'] = df['resolution (px)'].apply(lambda x: x.split(' x ')[1]).astype(int)
df
# Out:
#         graphic card type                            communications  \
# 7233   dedicated graphics         [bluetooth, lan 10/100/1000 mbps]
# 5845   dedicated graphics       [wi-fi, bluetooth, lan 10/100 mbps]
# 5897  integrated graphics                        [wi-fi, bluetooth]
# 4870  integrated graphics       [wi-fi, bluetooth, lan 10/100 mbps]
# 2498   dedicated graphics  [wi-fi, bluetooth, lan 10/100/1000 mbps]
# ...                   ...                                       ...
# 9211   dedicated graphics  [wi-fi, bluetooth, lan 10/100/1000 mbps]
# 2748   dedicated graphics              [bluetooth, lan 10/100 mbps]
# 2072   dedicated graphics  [wi-fi, bluetooth, lan 10/100/1000 mbps]
# 4741   dedicated graphics              [bluetooth, lan 10/100 mbps]
# 6980   dedicated graphics              [bluetooth, lan 10/100 mbps]
#
#      resolution (px) CPU cores RAM size                  operating system  \
# 7233     1920 x 1080         4       32                       [no system]
# 5845      1366 x 768         4        8                 [windows 10 home]
# 5897     2560 x 1440         4        8                 [windows 10 home]
# 4870      1366 x 768         2        8                 [windows 10 home]
# 2498     1920 x 1080         4        8  [windows 8.1 home 64-bit, other]
# ...              ...       ...      ...                               ...
# 9211     1920 x 1080         4       32                 [windows 10 home]
# 2748      1600 x 900         4        8                 [windows 10 home]
# 2072     1920 x 1080         4        8                       [no system]
# 4741     1920 x 1080         4       12                       [no system]
# 6980     1920 x 1080         4       32                 [windows 10 home]
#
#      drive type                                      input devices  \
# 7233  ssd + hdd  [keyboard, touchpad, illuminated keyboard, num...
# 5845        ssd             [keyboard, touchpad, numeric keyboard]
# 5897        ssd         [keyboard, touchpad, illuminated keyboard]
# 4870        hdd             [keyboard, touchpad, numeric keyboard]
# 2498        hdd  [keyboard, touchpad, illuminated keyboard, num...
# ...         ...                                                ...
# 9211        ssd  [keyboard, touchpad, illuminated keyboard, num...
# 2748        hdd             [keyboard, touchpad, numeric keyboard]
# 2072  ssd + hdd  [keyboard, touchpad, illuminated keyboard, num...
# 4741  ssd + hdd         [keyboard, touchpad, illuminated keyboard]
# 6980        ssd         [keyboard, touchpad, illuminated keyboard]
#
#                                           multimedia RAM type  \
# 7233  [SD card reader, camera, speakers, microphone]     ddr4
# 5845  [SD card reader, camera, speakers, microphone]     ddr3
# 5897  [SD card reader, camera, speakers, microphone]     ddr4
# 4870  [SD card reader, camera, speakers, microphone]     ddr4
# 2498  [SD card reader, camera, speakers, microphone]     ddr3
# ...                                              ...      ...
# 9211  [SD card reader, camera, speakers, microphone]     ddr4
# 2748  [SD card reader, camera, speakers, microphone]     ddr3
# 2072  [SD card reader, camera, speakers, microphone]     ddr4
# 4741  [SD card reader, camera, speakers, microphone]     ddr4
# 6980                  [camera, speakers, microphone]     ddr4
#
#       CPU clock speed (GHz)      CPU model  drive memory size (GB)  \
# 7233                    2.6  intel core i7                  1250.0
# 5845                    2.4  intel core i7                   256.0
# 5897                    1.2      other CPU                   256.0
# 4870                    2.0  intel core i3                  1000.0
# 2498                    2.4  intel core i7                  1000.0
# ...                     ...            ...                     ...
# 9211                    2.8  intel core i7                   500.0
# 2748                    2.2  intel core i7                  1000.0
# 2072                    2.6  intel core i7                  1120.0
# 4741                    2.8  intel core i7                  1256.0
# 6980                    2.8  intel core i7                   240.0
#
#                warranty  screen size  buynow_price  resolution_x  resolution_y
# 7233  producer warranty           17       4999.00          1920          1080
# 5845    seller warranty           15       2649.00          1366           768
# 5897  producer warranty           12       4499.00          2560          1440
# 4870  producer warranty           15       2099.00          1366           768
# 2498  producer warranty           17       2699.00          1920          1080
# ...                 ...          ...           ...           ...           ...
# 9211  producer warranty           15       5599.00          1920          1080
# 2748    seller warranty           17       2925.36          1600           900
# 2072  producer warranty           17       3799.00          1920          1080
# 4741  producer warranty           15       5589.00          1920          1080
# 6980  producer warranty           15       8678.00          1920          1080
#
# [6109 rows x 18 columns]

# %%
# resolution (px) is divided into resolution_x and resolution_y
# drop resolution (px)
df = df.drop(columns=['resolution (px)'])

# %%
df.dtypes
# Out:
# graphic card type          object
# communications             object
# CPU cores                  object
# RAM size                   object
# operating system           object
# drive type                 object
# input devices              object
# multimedia                 object
# RAM type                   object
# CPU clock speed (GHz)     float64
# CPU model                  object
# drive memory size (GB)    float64
# warranty                   object
# screen size                 int64
# buynow_price              float64
# resolution_x                int64
# resolution_y                int64
# dtype: object

# %%
# put all numerical columns together
numerical_cols = ['CPU cores', 'RAM size', 'CPU clock speed (GHz)','drive memory size (GB)', 'screen size', 'resolution_x', 'resolution_y']
numerical_df = df[numerical_cols].astype(float)
numerical_df
# Out:
#       CPU cores  RAM size  CPU clock speed (GHz)  drive memory size (GB)  \
# 7233        4.0      32.0                    2.6                  1250.0
# 5845        4.0       8.0                    2.4                   256.0
# 5897        4.0       8.0                    1.2                   256.0
# 4870        2.0       8.0                    2.0                  1000.0
# 2498        4.0       8.0                    2.4                  1000.0
# ...         ...       ...                    ...                     ...
# 9211        4.0      32.0                    2.8                   500.0
# 2748        4.0       8.0                    2.2                  1000.0
# 2072        4.0       8.0                    2.6                  1120.0
# 4741        4.0      12.0                    2.8                  1256.0
# 6980        4.0      32.0                    2.8                   240.0
#
#       screen size  resolution_x  resolution_y
# 7233         17.0        1920.0        1080.0
# 5845         15.0        1366.0         768.0
# 5897         12.0        2560.0        1440.0
# 4870         15.0        1366.0         768.0
# 2498         17.0        1920.0        1080.0
# ...           ...           ...           ...
# 9211         15.0        1920.0        1080.0
# 2748         17.0        1600.0         900.0
# 2072         17.0        1920.0        1080.0
# 4741         15.0        1920.0        1080.0
# 6980         15.0        1920.0        1080.0
#
# [6109 rows x 7 columns]

# %%
# use get_dummies( ) from pandas library to convert operating system column as categories
dummies_df = df['operating system'].str.join('|').str.get_dummies()
dummies_df
# Out:
#       no system  other  windows 10 home  windows 10 professional  \
# 7233          1      0                0                        0
# 5845          0      0                1                        0
# 5897          0      0                1                        0
# 4870          0      0                1                        0
# 2498          0      1                0                        0
# ...         ...    ...              ...                      ...
# 9211          0      0                1                        0
# 2748          0      0                1                        0
# 2072          1      0                0                        0
# 4741          1      0                0                        0
# 6980          0      0                1                        0
#
#       windows 7 home 64-bit  windows 7 professional 32-bit  \
# 7233                      0                              0
# 5845                      0                              0
# 5897                      0                              0
# 4870                      0                              0
# 2498                      0                              0
# ...                     ...                            ...
# 9211                      0                              0
# 2748                      0                              0
# 2072                      0                              0
# 4741                      0                              0
# 6980                      0                              0
#
#       windows 7 professional 64-bit  windows 8.1 home 32-bit  \
# 7233                              0                        0
# 5845                              0                        0
# 5897                              0                        0
# 4870                              0                        0
# 2498                              0                        0
# ...                             ...                      ...
# 9211                              0                        0
# 2748                              0                        0
# 2072                              0                        0
# 4741                              0                        0
# 6980                              0                        0
#
#       windows 8.1 home 64-bit  windows 8.1 professional 32-bit  \
# 7233                        0                                0
# 5845                        0                                0
# 5897                        0                                0
# 4870                        0                                0
# 2498                        1                                0
# ...                       ...                              ...
# 9211                        0                                0
# 2748                        0                                0
# 2072                        0                                0
# 4741                        0                                0
# 6980                        0                                0
#
#       windows 8.1 professional 64-bit
# 7233                                0
# 5845                                0
# 5897                                0
# 4870                                0
# 2498                                0
# ...                               ...
# 9211                                0
# 2748                                0
# 2072                                0
# 4741                                0
# 6980                                0
#
# [6109 rows x 11 columns]

# %%
# apply same logic to other suitable variables
dummy_cols = ['drive type', 'RAM type', 'CPU model']
for col in dummy_cols:
    col_dummies_df = df[col].str.get_dummies()
    dummies_df = pd.concat([dummies_df, col_dummies_df], axis=1)

dummies_df
# Out:
#       no system  other  windows 10 home  windows 10 professional  \
# 7233          1      0                0                        0
# 5845          0      0                1                        0
# 5897          0      0                1                        0
# 4870          0      0                1                        0
# 2498          0      1                0                        0
# ...         ...    ...              ...                      ...
# 9211          0      0                1                        0
# 2748          0      0                1                        0
# 2072          1      0                0                        0
# 4741          1      0                0                        0
# 6980          0      0                1                        0
#
#       windows 7 home 64-bit  windows 7 professional 32-bit  \
# 7233                      0                              0
# 5845                      0                              0
# 5897                      0                              0
# 4870                      0                              0
# 2498                      0                              0
# ...                     ...                            ...
# 9211                      0                              0
# 2748                      0                              0
# 2072                      0                              0
# 4741                      0                              0
# 6980                      0                              0
#
#       windows 7 professional 64-bit  windows 8.1 home 32-bit  \
# 7233                              0                        0
# 5845                              0                        0
# 5897                              0                        0
# 4870                              0                        0
# 2498                              0                        0
# ...                             ...                      ...
# 9211                              0                        0
# 2748                              0                        0
# 2072                              0                        0
# 4741                              0                        0
# 6980                              0                        0
#
#       windows 8.1 home 64-bit  windows 8.1 professional 32-bit  ...  \
# 7233                        0                                0  ...
# 5845                        0                                0  ...
# 5897                        0                                0  ...
# 4870                        0                                0  ...
# 2498                        1                                0  ...
# ...                       ...                              ...  ...
# 9211                        0                                0  ...
# 2748                        0                                0  ...
# 2072                        0                                0  ...
# 4741                        0                                0  ...
# 6980                        0                                0  ...
#
#       intel celeron dual-core  intel celeron m  intel celeron quad core   \
# 7233                        0                0                         0
# 5845                        0                0                         0
# 5897                        0                0                         0
# 4870                        0                0                         0
# 2498                        0                0                         0
# ...                       ...              ...                       ...
# 9211                        0                0                         0
# 2748                        0                0                         0
# 2072                        0                0                         0
# 4741                        0                0                         0
# 6980                        0                0                         0
#
#       intel core i3  intel core i5  intel core i7  intel core m  \
# 7233              0              0              1             0
# 5845              0              0              1             0
# 5897              0              0              0             0
# 4870              1              0              0             0
# 2498              0              0              1             0
# ...             ...            ...            ...           ...
# 9211              0              0              1             0
# 2748              0              0              1             0
# 2072              0              0              1             0
# 4741              0              0              1             0
# 6980              0              0              1             0
#
#       intel pentium dual-core  intel pentium quad-core   other CPU
# 7233                        0                         0          0
# 5845                        0                         0          0
# 5897                        0                         0          1
# 4870                        0                         0          0
# 2498                        0                         0          0
# ...                       ...                       ...        ...
# 9211                        0                         0          0
# 2748                        0                         0          0
# 2072                        0                         0          0
# 4741                        0                         0          0
# 6980                        0                         0          0
#
# [6109 rows x 36 columns]

# %%
# check remaining columns
label_col = ['buynow_price']
categorical_columns = [col for col in df.columns.to_list() if col not in compact_cols + label_col + numerical_cols + ['operating system'] + dummy_cols]
categorical_columns
# Out:
# ['graphic card type', 'warranty']

# %%
# encode them
categorical_df = pd.get_dummies(df[categorical_columns])
categorical_df
# Out:
#       graphic card type_dedicated graphics  \
# 7233                                  True
# 5845                                  True
# 5897                                 False
# 4870                                 False
# 2498                                  True
# ...                                    ...
# 9211                                  True
# 2748                                  True
# 2072                                  True
# 4741                                  True
# 6980                                  True
#
#       graphic card type_integrated graphics  warranty_producer warranty  \
# 7233                                  False                        True
# 5845                                  False                       False
# 5897                                   True                        True
# 4870                                   True                        True
# 2498                                  False                        True
# ...                                     ...                         ...
# 9211                                  False                        True
# 2748                                  False                       False
# 2072                                  False                        True
# 4741                                  False                        True
# 6980                                  False                        True
#
#       warranty_seller warranty
# 7233                     False
# 5845                      True
# 5897                     False
# 4870                     False
# 2498                     False
# ...                        ...
# 9211                     False
# 2748                      True
# 2072                     False
# 4741                     False
# 6980                     False
#
# [6109 rows x 4 columns]

# %%
# put unique_vals to compact_df columns
unique_cols = list()
for col in compact_cols:
    unique_cols += compact_dict[col]
compact_df = pd.DataFrame(columns = unique_cols , index=df.index, data=np.zeros((df.shape[0], len(unique_cols))))
compact_df
# Out:
#       bluetooth  wi-fi  wi-fi 802.11 b/g/n/ac  lan 10/100 mbps  \
# 7233        0.0    0.0                    0.0              0.0
# 5845        0.0    0.0                    0.0              0.0
# 5897        0.0    0.0                    0.0              0.0
# 4870        0.0    0.0                    0.0              0.0
# 2498        0.0    0.0                    0.0              0.0
# ...         ...    ...                    ...              ...
# 9211        0.0    0.0                    0.0              0.0
# 2748        0.0    0.0                    0.0              0.0
# 2072        0.0    0.0                    0.0              0.0
# 4741        0.0    0.0                    0.0              0.0
# 6980        0.0    0.0                    0.0              0.0
#
#       wi-fi 802.11 a/b/g/n/ac  nfc (near field communication)  \
# 7233                      0.0                             0.0
# 5845                      0.0                             0.0
# 5897                      0.0                             0.0
# 4870                      0.0                             0.0
# 2498                      0.0                             0.0
# ...                       ...                             ...
# 9211                      0.0                             0.0
# 2748                      0.0                             0.0
# 2072                      0.0                             0.0
# 4741                      0.0                             0.0
# 6980                      0.0                             0.0
#
#       lan 10/100/1000 mbps  gps  wi-fi 802.11 b/g/n  \
# 7233                   0.0  0.0                 0.0
# 5845                   0.0  0.0                 0.0
# 5897                   0.0  0.0                 0.0
# 4870                   0.0  0.0                 0.0
# 2498                   0.0  0.0                 0.0
# ...                    ...  ...                 ...
# 9211                   0.0  0.0                 0.0
# 2748                   0.0  0.0                 0.0
# 2072                   0.0  0.0                 0.0
# 4741                   0.0  0.0                 0.0
# 6980                   0.0  0.0                 0.0
#
#       intel wireless display (widi)  ...  modem 3g (wwan)  modem 4g (lte)  \
# 7233                            0.0  ...              0.0             0.0
# 5845                            0.0  ...              0.0             0.0
# 5897                            0.0  ...              0.0             0.0
# 4870                            0.0  ...              0.0             0.0
# 2498                            0.0  ...              0.0             0.0
# ...                             ...  ...              ...             ...
# 9211                            0.0  ...              0.0             0.0
# 2748                            0.0  ...              0.0             0.0
# 2072                            0.0  ...              0.0             0.0
# 4741                            0.0  ...              0.0             0.0
# 6980                            0.0  ...              0.0             0.0
#
#       keyboard  touchpad  illuminated keyboard  numeric keyboard  \
# 7233       0.0       0.0                   0.0               0.0
# 5845       0.0       0.0                   0.0               0.0
# 5897       0.0       0.0                   0.0               0.0
# 4870       0.0       0.0                   0.0               0.0
# 2498       0.0       0.0                   0.0               0.0
# ...        ...       ...                   ...               ...
# 9211       0.0       0.0                   0.0               0.0
# 2748       0.0       0.0                   0.0               0.0
# 2072       0.0       0.0                   0.0               0.0
# 4741       0.0       0.0                   0.0               0.0
# 6980       0.0       0.0                   0.0               0.0
#
#       SD card reader  camera  microphone  speakers
# 7233             0.0     0.0         0.0       0.0
# 5845             0.0     0.0         0.0       0.0
# 5897             0.0     0.0         0.0       0.0
# 4870             0.0     0.0         0.0       0.0
# 2498             0.0     0.0         0.0       0.0
# ...              ...     ...         ...       ...
# 9211             0.0     0.0         0.0       0.0
# 2748             0.0     0.0         0.0       0.0
# 2072             0.0     0.0         0.0       0.0
# 4741             0.0     0.0         0.0       0.0
# 6980             0.0     0.0         0.0       0.0
#
# [6109 rows x 21 columns]

# %%
# get the values of compact_df from original dataframe
# If the computer includes the column name as a feature assign 1, otherwise 0
for col, unique_list in compact_dict.items():
    for unique in unique_list:
        compact_df[unique] = df[col].apply(lambda x: 1 if unique in x else 0)

compact_df
# Out:
#       bluetooth  wi-fi  wi-fi 802.11 b/g/n/ac  lan 10/100 mbps  \
# 7233          1      0                      0                0
# 5845          1      1                      0                1
# 5897          1      1                      0                0
# 4870          1      1                      0                1
# 2498          1      1                      0                0
# ...         ...    ...                    ...              ...
# 9211          1      1                      0                0
# 2748          1      0                      0                1
# 2072          1      1                      0                0
# 4741          1      0                      0                1
# 6980          1      0                      0                1
#
#       wi-fi 802.11 a/b/g/n/ac  nfc (near field communication)  \
# 7233                        0                               0
# 5845                        0                               0
# 5897                        0                               0
# 4870                        0                               0
# 2498                        0                               0
# ...                       ...                             ...
# 9211                        0                               0
# 2748                        0                               0
# 2072                        0                               0
# 4741                        0                               0
# 6980                        0                               0
#
#       lan 10/100/1000 mbps  gps  wi-fi 802.11 b/g/n  \
# 7233                     1    0                   0
# 5845                     0    0                   0
# 5897                     0    0                   0
# 4870                     0    0                   0
# 2498                     1    0                   0
# ...                    ...  ...                 ...
# 9211                     1    0                   0
# 2748                     0    0                   0
# 2072                     1    0                   0
# 4741                     0    0                   0
# 6980                     0    0                   0
#
#       intel wireless display (widi)  ...  modem 3g (wwan)  modem 4g (lte)  \
# 7233                              0  ...                0               0
# 5845                              0  ...                0               0
# 5897                              0  ...                0               0
# 4870                              0  ...                0               0
# 2498                              0  ...                0               0
# ...                             ...  ...              ...             ...
# 9211                              0  ...                0               0
# 2748                              0  ...                0               0
# 2072                              0  ...                0               0
# 4741                              0  ...                0               0
# 6980                              0  ...                0               0
#
#       keyboard  touchpad  illuminated keyboard  numeric keyboard  \
# 7233         1         1                     1                 1
# 5845         1         1                     0                 1
# 5897         1         1                     1                 0
# 4870         1         1                     0                 1
# 2498         1         1                     1                 1
# ...        ...       ...                   ...               ...
# 9211         1         1                     1                 1
# 2748         1         1                     0                 1
# 2072         1         1                     1                 1
# 4741         1         1                     1                 0
# 6980         1         1                     1                 0
#
#       SD card reader  camera  microphone  speakers
# 7233               1       1           1         1
# 5845               1       1           1         1
# 5897               1       1           1         1
# 4870               1       1           1         1
# 2498               1       1           1         1
# ...              ...     ...         ...       ...
# 9211               1       1           1         1
# 2748               1       1           1         1
# 2072               1       1           1         1
# 4741               1       1           1         1
# 6980               0       1           1         1
#
# [6109 rows x 21 columns]

# %%
# concatenate all processed dataframe to put together
new_df = pd.concat([categorical_df, numerical_df, compact_df, dummies_df],axis=1)
new_df.head(5)
# Out:
#       graphic card type_dedicated graphics  \
# 7233                                  True
# 5845                                  True
# 5897                                 False
# 4870                                 False
# 2498                                  True
#
#       graphic card type_integrated graphics  warranty_producer warranty  \
# 7233                                  False                        True
# 5845                                  False                       False
# 5897                                   True                        True
# 4870                                   True                        True
# 2498                                  False                        True
#
#       warranty_seller warranty  CPU cores  RAM size  CPU clock speed (GHz)  \
# 7233                     False        4.0      32.0                    2.6
# 5845                      True        4.0       8.0                    2.4
# 5897                     False        4.0       8.0                    1.2
# 4870                     False        2.0       8.0                    2.0
# 2498                     False        4.0       8.0                    2.4
#
#       drive memory size (GB)  screen size  resolution_x  ...  \
# 7233                  1250.0         17.0        1920.0  ...
# 5845                   256.0         15.0        1366.0  ...
# 5897                   256.0         12.0        2560.0  ...
# 4870                  1000.0         15.0        1366.0  ...
# 2498                  1000.0         17.0        1920.0  ...
#
#       intel celeron dual-core  intel celeron m  intel celeron quad core   \
# 7233                        0                0                         0
# 5845                        0                0                         0
# 5897                        0                0                         0
# 4870                        0                0                         0
# 2498                        0                0                         0
#
#       intel core i3  intel core i5  intel core i7  intel core m  \
# 7233              0              0              1             0
# 5845              0              0              1             0
# 5897              0              0              0             0
# 4870              1              0              0             0
# 2498              0              0              1             0
#
#       intel pentium dual-core  intel pentium quad-core   other CPU
# 7233                        0                         0          0
# 5845                        0                         0          0
# 5897                        0                         0          1
# 4870                        0                         0          0
# 2498                        0                         0          0
#
# [5 rows x 68 columns]

# %% [markdown]
# # **Multicollinearity Check**
# Multicollinearity is a potential problem for this regression task. We will check it through Variance Inflation Factor (VIF). We will eliminate all features that have VIF score above 20. For each iteration, we will drop only one feature, since when the feature set is changed VIF scores also change.

# %%
import pandas as pd
import numpy as np
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
# compute VIF score with variance_inflation_factor() function
def compute_vif(features):
    vif_data = pd.DataFrame()
    # Convert the subset of the DataFrame to numeric,
    # coercing errors to NaN and then dropping rows with NaNs.
    # Select only numeric columns and drop rows with any missing values
    X = new_df[features].select_dtypes(include=np.number) # Remove .dropna()
    # One-hot encode categorical columns if present
    X = pd.get_dummies(X, columns=X.select_dtypes(include=['object', 'category']).columns)
    # Reset index to ensure matching lengths
    X = X.reset_index(drop=True).dropna()  # Apply dropna() after get_dummies
    vif_data["feature"] = X.columns  # Update to reflect columns after get_dummies
    vif_data["VIF"] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]
    return vif_data.sort_values(by=['VIF']).reset_index(drop=True)

# %%
# apply VIF computation to all columns
features = new_df.columns.to_list()
vif_data = compute_vif(features)
vif_data
# Out:
# /usr/local/lib/python3.11/dist-packages/statsmodels/stats/outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
#                             feature       VIF
# 0             windows 7 home 64-bit  1.027750
# 1   windows 8.1 professional 32-bit  1.031814
# 2     windows 7 professional 32-bit  1.034460
# 3              wi-fi 802.11 a/b/g/n  1.069641
# 4           wi-fi 802.11 a/b/g/n/ac  1.120634
# ..                              ...       ...
# 59                           hybrid       inf
# 60                              hdd       inf
# 61                             emmc       inf
# 62                           amd a6       inf
# 63                        other CPU       inf
#
# [64 rows x 2 columns]

# %%
# drop with highest vif score until all vif scores are under 20
multicollinearity = True

while multicollinearity:
    highest_vif_feature = vif_data['feature'].values.tolist()[-1]
    print("I will remove", highest_vif_feature)
    features.remove(highest_vif_feature)
    vif_data = compute_vif(features)
    multicollinearity = False if len(vif_data[vif_data.VIF > 20]) == 0 else True

selected_features = vif_data['feature'].values.tolist()
vif_data
# Out:
# I will remove other CPU
# /usr/local/lib/python3.11/dist-packages/statsmodels/stats/outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# I will remove hdd
# I will remove ddr4
# I will remove resolution_x
# I will remove touchpad
# I will remove screen size
# I will remove camera
# I will remove CPU clock speed (GHz)
# I will remove windows 10 home
# I will remove intel core i7
# I will remove keyboard
# I will remove bluetooth
# I will remove CPU cores
# I will remove resolution_y
#                             feature        VIF
# 0   windows 8.1 professional 32-bit   1.003809
# 1             windows 7 home 64-bit   1.007310
# 2                   intel celeron m   1.014100
# 3     windows 7 professional 32-bit   1.017267
# 4                      intel core m   1.026308
# 5           windows 8.1 home 32-bit   1.027115
# 6                            amd a4   1.031958
# 7                            amd e1   1.033196
# 8                           amd a10   1.040190
# 9                           amd a12   1.058642
# 10                           hybrid   1.067349
# 11             wi-fi 802.11 a/b/g/n   1.067608
# 12                           amd a8   1.073661
# 13  windows 8.1 professional 64-bit   1.078143
# 14         intel celeron quad core    1.097492
# 15         intel pentium quad-core    1.105225
# 16               wi-fi 802.11 b/g/n   1.108316
# 17          wi-fi 802.11 a/b/g/n/ac   1.130758
# 18            wi-fi 802.11 b/g/n/ac   1.138977
# 19                   intel celeron    1.152942
# 20          windows 8.1 home 64-bit   1.229752
# 21                           amd a6   1.233079
# 22          intel celeron dual-core   1.259629
# 23                             emmc   1.273375
# 24    windows 7 professional 64-bit   1.323926
# 25          intel pentium dual-core   1.388364
# 26                            other   1.528748
# 27                            ddr3l   1.548408
# 28                        no system   1.566744
# 29          windows 10 professional   1.737613
# 30                   modem 4g (lte)   1.838992
# 31                        ssd + hdd   2.161087
# 32                              gps   2.165594
# 33                    intel core i5   2.281815
# 34                    intel core i3   2.406999
# 35                             ddr3   2.588843
# 36                            wi-fi   3.621366
# 37             illuminated keyboard   3.724240
# 38                  lan 10/100 mbps   4.080728
# 39                 numeric keyboard   4.368419
# 40                         RAM size   4.464195
# 41                              ssd   4.590356
# 42    intel wireless display (widi)   4.755716
# 43                  modem 3g (wwan)   4.865520
# 44   nfc (near field communication)   6.280559
# 45             lan 10/100/1000 mbps   6.620121
# 46           drive memory size (GB)   7.693896
# 47                   SD card reader  14.561399
# 48                         speakers  15.568505
# 49                       microphone  16.275451

# %%
import seaborn as sns
from matplotlib import pyplot as plt

# %%
# correlation matrix of multicollinearity free dataset
plt.figure(figsize=(20, 20)) # width and height in inches
corr_df = pd.concat([new_df[selected_features], df[label_col]], axis=1)
sns.heatmap(corr_df.corr(),annot=True, lw=1)
plt.show()

# %% [markdown]
# # **Train/Val/Test Split**

# %%
# use the indeces of given datasets to properly separate it again as initial datasets
train_indeces = train_df.dropna().index
val_indeces = val_df.dropna().index
test_indeces = test_df.dropna().index

# %%
train_df = new_df.loc[train_indeces]
val_df = new_df.loc[val_indeces]
test_df = new_df.loc[test_indeces]

# %%
# sklearn machine learning models expect y_train, y_test, y_val
# in the shape as (row_number, ) instead of (row_number, 1) shape, so apply .ravel()
X_train, X_val, X_test = train_df[selected_features].to_numpy(), val_df[selected_features].to_numpy(), test_df[selected_features].to_numpy()
y_train, y_val, y_test = df.loc[train_indeces][label_col].to_numpy().ravel(), df.loc[val_indeces][label_col].to_numpy().ravel(), df.loc[test_indeces][label_col].to_numpy().ravel()

# %%
X_train.shape
# Out:
# (3694, 50)

# %%
y_train.shape
# Out:
# (3694,)

# %% [markdown]
# # **Classical Machine Learning**
# We will implement and try different machine learning models from Linear Regression to Ensemble Methods. We will measure root-mean-squared-error as instructed. We will scale our data with MaxAbsScaler() from sklearn, which works well with sparse datasets.

# %%
import numpy as np
import pandas as pd

from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.ensemble import ExtraTreesRegressor
from sklearn.ensemble import VotingRegressor
from sklearn import linear_model
from sklearn.neural_network import MLPRegressor

from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler, MaxAbsScaler

import matplotlib.pyplot as plt
from sklearn import tree
import seaborn as sns


def rmse(y_true, y_pred):
    """
    Calculate the Root Mean Squared Error (RMSE).

    If the 'squared' argument is not supported by mean_squared_error,
    calculate the RMSE manually.
    """
    try:
        # Try using the 'squared' argument
        mse = mean_squared_error(y_true, y_pred, squared=False)
    except TypeError:
        # If 'squared' is not supported, calculate RMSE manually
        mse = mean_squared_error(y_true, y_pred)
        mse = np.sqrt(mse)  # Take the square root to get RMSE

    return mse


def regression(regressor_name, regressor):
    # alternative scaler
    # pipe = make_pipeline(StandardScaler(), regressor)
    pipe = make_pipeline(MaxAbsScaler(), regressor)
    pipe.fit(X_train, y_train)
    predicted = pipe.predict(X_test)
    rmse_val = rmse(y_test, predicted)
    print(regressor_name, ":", rmse_val)
    pred_df[regressor_name + "_Pred"] = predicted
    plt.figure(regressor_name)
    plt.title(regressor_name)
    plt.xlabel("predicted")
    plt.ylabel("actual")
    sns.regplot(y=y_test, x=predicted)


regressors = {
    "Linear": LinearRegression(),
    "MLP": MLPRegressor(
        random_state=42, max_iter=500, learning_rate="constant", learning_rate_init=0.6
    ),
    "DecisionTree": DecisionTreeRegressor(max_depth=15, random_state=42),
    "RandomForest": RandomForestRegressor(random_state=42),
    "GradientBoosting": GradientBoostingRegressor(
        random_state=42,
        criterion="squared_error",
        loss="squared_error",
        learning_rate=0.6,
        warm_start=True,
    ),
    "ExtraTrees": ExtraTreesRegressor(n_estimators=100, random_state=42),
}

pred_df = pd.DataFrame(columns=["Actual"])
pred_df["Actual"] = y_test

for key in regressors.keys():
    regression(key, regressors[key])
# Out:
# Linear : 794.4322090893723
# MLP : 929.1737544856878
# DecisionTree : 721.8544114428656
# RandomForest : 604.2753477464071
# GradientBoosting : 595.3663823907888
# ExtraTrees : 626.8981784469452

# %% [markdown]
# ## **Voting Regressor**

# %%
from sklearn.ensemble import VotingRegressor

# classifiers
reg1 = regressors["GradientBoosting"]
reg2 = regressors["ExtraTrees"]
reg3 = regressors["RandomForest"]

# take the highest performed three models and combine them in a voting mechanism
# assign weights to their predictions and create new regressor
# it is possible to try with different weights
regression("Voting", VotingRegressor([("gb", reg1), ("et", reg2), ("rf", reg3)], weights=[0.4, 0.35, 0.25]))
# Out:
# Voting : 543.2265486185663

# %%
pred_df
# Out:
#        Actual  Linear_Pred     MLP_Pred  DecisionTree_Pred  RandomForest_Pred  \
# 0     2369.00  2373.597020  2292.609221        2222.333333        2222.893810
# 1     2299.00  2454.518684  2392.399630        2484.815789        2371.896667
# 2     5999.00  5071.691823  5040.808447        4965.666667        4996.982143
# 3     1299.00  1023.199263  1297.628429        1249.000000        1250.719246
# 4     3329.00  6673.546897  5779.298653        6949.000000        6663.369444
# ...       ...          ...          ...                ...                ...
# 1195  5599.00  5775.362437  5494.984232        5674.000000        5679.553571
# 1196  2925.36  3085.104468  2526.242418        2591.813200        2701.029150
# 1197  3799.00  4241.897667  4128.341788        4561.500000        4321.287000
# 1198  5589.00  5120.472392  4939.428678        4872.000000        4776.211333
# 1199  8678.00  8046.627665  8152.769963        8349.000000        7939.960000
#
#       GradientBoosting_Pred  ExtraTrees_Pred  Voting_Pred
# 0               2420.643428      2222.333333  2301.797490
# 1               2220.247044      2384.000000  2315.472984
# 2               5093.636196      4999.000000  5036.350014
# 3               1224.296853      1249.000000  1239.548553
# 4               4814.473279      6442.750000  5846.594173
# ...                     ...              ...          ...
# 1195            6188.638075      5674.000000  5881.243623
# 1196            2597.663560      2693.507500  2657.050336
# 1197            4016.085136      4195.530000  4155.191304
# 1198            5195.381640      4312.935000  4781.732739
# 1199            8108.833334      8214.350000  8103.545834
#
# [1200 rows x 8 columns]

# %% [markdown]
# It improves the performance of the RandomForest. We can go ahead with this voting model as our official solution.

# %% [markdown]
# # **Deep Learning**
# Another promising regression algorithm is artificial neural networks. We will create a small one with 4 hidden units since we have small data. We will use a scheduler to decrease the learning rate after a certain epoch number. Also, to prevent overfitting, we will use EarlyStopping.
#
# We will make a comparison between a complex model (two hidden layers) and a base model to see what works best.

# %%
import tensorflow as tf

from tensorflow import keras
from tensorflow.keras import layers

# set random for reproducibility
tf.random.set_seed(42)


# define the error metric using tensorflow functions
def root_mean_squared_error(y_true, y_pred):
    return tf.sqrt(tf.reduce_mean(tf.square(y_pred - y_true)))  # Use tf functions

# define learning rate scheduler
def scheduler(epoch, lr):
    if epoch < 30:
        return lr
    else:
        # Convert the tensor to a NumPy float
        return float(lr * tf.math.exp(-0.01)) # change to return float instead of tf.Tensor


# define base model architecture
def build_and_compile_base_model():
    model = keras.Sequential([
        layers.Normalization(axis=-1),
        layers.Dense(64, activation='relu'),
        layers.Dropout(0.2),
        layers.Dense(4, activation='relu'),
        layers.Dense(1)
    ])

    model.compile(loss=root_mean_squared_error,  # Use the custom loss function
                optimizer=tf.keras.optimizers.Adam(0.005))
    model.build(input_shape=(None,len(selected_features)))
    return model

# define complex model architecture
def build_and_compile_complex_model():
    model = keras.Sequential([
        layers.Normalization(axis=-1),
        layers.Dense(64, activation='relu'),
        layers.Dropout(0.2),
        layers.Dense(8, activation='relu'),
        layers.Dense(8, activation='relu'),
        layers.Dense(1)
    ])

    model.compile(loss=root_mean_squared_error,  # Use the custom loss function
                optimizer=tf.keras.optimizers.Adam(0.005))
    model.build(input_shape=(None,len(selected_features)))
    return model

# %%
# compile base model
dnn_model = build_and_compile_base_model()

# %%
dnn_model.summary()
# Out:
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ normalization_2 (Normalization)      │ (None, 50)                  │             101 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_6 (Dense)                      │ (None, 64)                  │           3,264 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_2 (Dropout)                  │ (None, 64)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_7 (Dense)                      │ (None, 4)                   │             260 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_8 (Dense)                      │ (None, 1)                   │               5 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 3,630 (14.18 KB)
#  Trainable params: 3,529 (13.79 KB)
#  Non-trainable params: 101 (408.00 B)

# %%
# initialize scheduler and early stopping callback
scheduler_c = tf.keras.callbacks.LearningRateScheduler(scheduler)
early_stopping = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss', min_delta=0, patience=20, verbose=1,
    mode='auto', baseline=None, restore_best_weights=True)

# train base model
history = dnn_model.fit(
    X_train,
    y_train,
    validation_data=(X_val, y_val),
    callbacks = [scheduler_c, early_stopping],
    verbose=1, epochs=400)
# Out:
# Epoch 1/400
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 2969.0610 - val_loss: 2177.1531 - learning_rate: 0.0050
# Epoch 2/400
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2198.1021 - val_loss: 2064.4065 - learning_rate: 0.0050
# Epoch 3/400
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1988.3575 - val_loss: 1528.4545 - learning_rate: 0.0050
# Epoch 4/400
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1492.0972 - val_loss: 1311.0830 - learning_rate: 0.0050
# Epoch 5/400
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 1357.2585 - val_loss: 1247.5426 - learning_rate: 0.0050
# Epoch 6/400
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 1318.1254 - val_loss: 1202.5778 - learning_rate: 0.0050
# Epoch 7/400
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 1254.4513 - val_loss: 1160.9106 - learning_rate: 0.0050
# Epoch 8/400
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 1223.1687 - val_loss: 1127.4219 - learning_rate: 0.0050
# Epoch 9/400
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 1184.9407 - val_loss: 1099.3132 - learning_rate: 0.0050
# Epoch 10/400
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1154.4209 - val_loss: 1047.3636 - learning_rate: 0.0050
# Epoch 11/400
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 1111.5459 - val_loss: 1016.9933 - learning_rate: 0.0050
# Epoch 12/400
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1106.1732 - val_loss: 1000.4910 - learning_rate: 0.0050
# Epoch 13/400
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 1078.2516 - val_loss: 955.7955 - learning_rate: 0.0050
# Epoch 14/400
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1062.4166 - val_loss: 927.6676 - learning_rate: 0.0050
# Epoch 15/400
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1021.9315 - val_loss: 905.0213 - learning_rate: 0.0050
# Epoch 16/400
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1015.8680 - val_loss: 889.8799 - learning_rate: 0.0050
# Epoch 17/400
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 998.2926 - val_loss: 865.5953 - learning_rate: 0.0050
# Epoch 18/400
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 985.8129 - val_loss: 866.4120 - learning_rate: 0.0050
# Epoch 19/400
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1011.5451 - val_loss: 847.9179 - learning_rate: 0.0050
# Epoch 20/400
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 987.1500 - val_loss: 883.8045 - learning_rate: 0.0050
# Epoch 21/400
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 976.8393 - val_loss: 834.4639 - learning_rate: 0.0050
# Epoch 22/400
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 966.9617 - val_loss: 819.1571 - learning_rate: 0.0050
# Epoch 23/400
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 986.4902 - val_loss: 816.9370 - learning_rate: 0.0050
# Epoch 24/400
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 939.6912 - val_loss: 817.9197 - learning_rate: 0.0050
# Epoch 25/400
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 953.0811 - val_loss: 801.7941 - learning_rate: 0.0050
# Epoch 26/400
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 936.9521 - val_loss: 801.6824 - learning_rate: 0.0050
# Epoch 27/400
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 954.7803 - val_loss: 810.4371 - learning_rate: 0.0050
# Epoch 28/400
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 933.0046 - val_loss: 790.7916 - learning_rate: 0.0050
# Epoch 29/400
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 953.3867 - val_loss: 802.2216 - learning_rate: 0.0050
# Epoch 30/400
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 942.1130 - val_loss: 785.2589 - learning_rate: 0.0050
# Epoch 31/400
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 913.2976 - val_loss: 781.9865 - learning_rate: 0.0050
# Epoch 32/400
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 922.2422 - val_loss: 779.5525 - learning_rate: 0.0049
# Epoch 33/400
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 917.5047 - val_loss: 787.2539 - learning_rate: 0.0049
# Epoch 34/400
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 902.5814 - val_loss: 787.3541 - learning_rate: 0.0048
# Epoch 35/400
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 919.0732 - val_loss: 770.1243 - learning_rate: 0.0048
# Epoch 36/400
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 908.5197 - val_loss: 784.6522 - learning_rate: 0.0047
# Epoch 37/400
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 920.5329 - val_loss: 767.0414 - learning_rate: 0.0047
# Epoch 38/400
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 901.8991 - val_loss: 765.1781 - learning_rate: 0.0046
# Epoch 39/400
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 894.7756 - val_loss: 769.0918 - learning_rate: 0.0046
# Epoch 40/400
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 895.0917 - val_loss: 762.0881 - learning_rate: 0.0045
# Epoch 41/400
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 910.1596 - val_loss: 758.6549 - learning_rate: 0.0045
# Epoch 42/400
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 902.8487 - val_loss: 764.4050 - learning_rate: 0.0044
# Epoch 43/400
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 891.2281 - val_loss: 762.4214 - learning_rate: 0.0044
# Epoch 44/400
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 901.8997 - val_loss: 751.1617 - learning_rate: 0.0043
# Epoch 45/400
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 885.1682 - val_loss: 748.9969 - learning_rate: 0.0043
# Epoch 46/400
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 893.5832 - val_loss: 747.6029 - learning_rate: 0.0043
# Epoch 47/400
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 888.1002 - val_loss: 762.3115 - learning_rate: 0.0042
# Epoch 48/400
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 893.6008 - val_loss: 744.3132 - learning_rate: 0.0042
# Epoch 49/400
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 884.8889 - val_loss: 752.0648 - learning_rate: 0.0041
# Epoch 50/400
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 865.7298 - val_loss: 737.0886 - learning_rate: 0.0041
# Epoch 51/400
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 876.6546 - val_loss: 741.1091 - learning_rate: 0.0041
# Epoch 52/400
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 882.3481 - val_loss: 752.4030 - learning_rate: 0.0040
# Epoch 53/400
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 886.9033 - val_loss: 732.3702 - learning_rate: 0.0040
# Epoch 54/400
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 873.4567 - val_loss: 734.5142 - learning_rate: 0.0039
# Epoch 55/400
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 836.5069 - val_loss: 727.4125 - learning_rate: 0.0039
# Epoch 56/400
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 871.7759 - val_loss: 731.0103 - learning_rate: 0.0039
# Epoch 57/400
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 879.0750 - val_loss: 729.5931 - learning_rate: 0.0038
# Epoch 58/400
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 857.3445 - val_loss: 729.5352 - learning_rate: 0.0038
# Epoch 59/400
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 867.2870 - val_loss: 720.4736 - learning_rate: 0.0037
# Epoch 60/400
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 869.3853 - val_loss: 739.3060 - learning_rate: 0.0037
# Epoch 61/400
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 854.2443 - val_loss: 717.6332 - learning_rate: 0.0037
# Epoch 62/400
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 869.4961 - val_loss: 760.6406 - learning_rate: 0.0036
# Epoch 63/400
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 872.9658 - val_loss: 731.0994 - learning_rate: 0.0036
# Epoch 64/400
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 860.0372 - val_loss: 719.8158 - learning_rate: 0.0036
# Epoch 65/400
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 853.1194 - val_loss: 721.1389 - learning_rate: 0.0035
# Epoch 66/400
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 856.9484 - val_loss: 712.0742 - learning_rate: 0.0035
# Epoch 67/400
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 845.0900 - val_loss: 725.7136 - learning_rate: 0.0035
# Epoch 68/400
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 856.4285 - val_loss: 712.1584 - learning_rate: 0.0034
# Epoch 69/400
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 844.3741 - val_loss: 707.4478 - learning_rate: 0.0034
# Epoch 70/400
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 851.7196 - val_loss: 710.8891 - learning_rate: 0.0034
# Epoch 71/400
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 840.6085 - val_loss: 714.1982 - learning_rate: 0.0033
# Epoch 72/400
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 840.2306 - val_loss: 707.3273 - learning_rate: 0.0033
# Epoch 73/400
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 840.3432 - val_loss: 711.8774 - learning_rate: 0.0033
# Epoch 74/400
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 839.0096 - val_loss: 721.5338 - learning_rate: 0.0032
# Epoch 75/400
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 839.4072 - val_loss: 706.2773 - learning_rate: 0.0032
# Epoch 76/400
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 841.5261 - val_loss: 700.1998 - learning_rate: 0.0032
# Epoch 77/400
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 845.5203 - val_loss: 708.2689 - learning_rate: 0.0031
# Epoch 78/400
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 849.3486 - val_loss: 697.3035 - learning_rate: 0.0031
# Epoch 79/400
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 833.0422 - val_loss: 717.8063 - learning_rate: 0.0031
# Epoch 80/400
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 861.9595 - val_loss: 699.2416 - learning_rate: 0.0030
# Epoch 81/400
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 815.5771 - val_loss: 696.0974 - learning_rate: 0.0030
# Epoch 82/400
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 806.5228 - val_loss: 693.5784 - learning_rate: 0.0030
# Epoch 83/400
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 823.0315 - val_loss: 697.9235 - learning_rate: 0.0029
# Epoch 84/400
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 842.8418 - val_loss: 692.4396 - learning_rate: 0.0029
# Epoch 85/400
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 821.0250 - val_loss: 697.0806 - learning_rate: 0.0029
# Epoch 86/400
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 814.7020 - val_loss: 693.1322 - learning_rate: 0.0029
# Epoch 87/400
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 806.2821 - val_loss: 697.7531 - learning_rate: 0.0028
# Epoch 88/400
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 826.3680 - val_loss: 696.6105 - learning_rate: 0.0028
# Epoch 89/400
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 823.4282 - val_loss: 695.0482 - learning_rate: 0.0028
# Epoch 90/400
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 827.5324 - val_loss: 695.4077 - learning_rate: 0.0027
# Epoch 91/400
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 810.4862 - val_loss: 686.8854 - learning_rate: 0.0027
# Epoch 92/400
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 822.0470 - val_loss: 685.0378 - learning_rate: 0.0027
# Epoch 93/400
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 824.2465 - val_loss: 689.0201 - learning_rate: 0.0027
# Epoch 94/400
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 816.4315 - val_loss: 697.1160 - learning_rate: 0.0026
# Epoch 95/400
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 826.5991 - val_loss: 681.1749 - learning_rate: 0.0026
# Epoch 96/400
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 816.3286 - val_loss: 684.8444 - learning_rate: 0.0026
# Epoch 97/400
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 815.9993 - val_loss: 681.3195 - learning_rate: 0.0026
# Epoch 98/400
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 822.1833 - val_loss: 682.2406 - learning_rate: 0.0025
# Epoch 99/400
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 813.4213 - val_loss: 683.9662 - learning_rate: 0.0025
# Epoch 100/400
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 827.5015 - val_loss: 681.5535 - learning_rate: 0.0025
# Epoch 101/400
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 820.6376 - val_loss: 685.3244 - learning_rate: 0.0025
# Epoch 102/400
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 818.9935 - val_loss: 676.2413 - learning_rate: 0.0024
# Epoch 103/400
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 817.7960 - val_loss: 678.5911 - learning_rate: 0.0024
# Epoch 104/400
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 823.3106 - val_loss: 677.1935 - learning_rate: 0.0024
# Epoch 105/400
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 801.2562 - val_loss: 677.0113 - learning_rate: 0.0024
# Epoch 106/400
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 819.6696 - val_loss: 697.0608 - learning_rate: 0.0023
# Epoch 107/400
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 816.6496 - val_loss: 678.6616 - learning_rate: 0.0023
# Epoch 108/400
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 808.5582 - val_loss: 679.2354 - learning_rate: 0.0023
# Epoch 109/400
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 832.6192 - val_loss: 674.2208 - learning_rate: 0.0023
# Epoch 110/400
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 809.9805 - val_loss: 674.1498 - learning_rate: 0.0022
# Epoch 111/400
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 818.9227 - val_loss: 703.8683 - learning_rate: 0.0022
# Epoch 112/400
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 802.6286 - val_loss: 673.5048 - learning_rate: 0.0022
# Epoch 113/400
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 811.9761 - val_loss: 672.2459 - learning_rate: 0.0022
# Epoch 114/400
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 830.4091 - val_loss: 684.0056 - learning_rate: 0.0022
# Epoch 115/400
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 811.1760 - val_loss: 685.1837 - learning_rate: 0.0021
# Epoch 116/400
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 808.6757 - val_loss: 682.2336 - learning_rate: 0.0021
# Epoch 117/400
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 827.8759 - val_loss: 671.6962 - learning_rate: 0.0021
# Epoch 118/400
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 803.9617 - val_loss: 670.3881 - learning_rate: 0.0021
# Epoch 119/400
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 822.6000 - val_loss: 682.3220 - learning_rate: 0.0021
# Epoch 120/400
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 800.0261 - val_loss: 676.3640 - learning_rate: 0.0020
# Epoch 121/400
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 818.3648 - val_loss: 669.2122 - learning_rate: 0.0020
# Epoch 122/400
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 820.3448 - val_loss: 669.3303 - learning_rate: 0.0020
# Epoch 123/400
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 808.6034 - val_loss: 670.2374 - learning_rate: 0.0020
# Epoch 124/400
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 822.7763 - val_loss: 671.4776 - learning_rate: 0.0020
# Epoch 125/400
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 812.0797 - val_loss: 669.4354 - learning_rate: 0.0019
# Epoch 126/400
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 784.7451 - val_loss: 677.2568 - learning_rate: 0.0019
# Epoch 127/400
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 803.5943 - val_loss: 667.4181 - learning_rate: 0.0019
# Epoch 128/400
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 799.0952 - val_loss: 666.5590 - learning_rate: 0.0019
# Epoch 129/400
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 799.3154 - val_loss: 672.1602 - learning_rate: 0.0019
# Epoch 130/400
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 794.1281 - val_loss: 668.3942 - learning_rate: 0.0018
# Epoch 131/400
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 830.6385 - val_loss: 667.7352 - learning_rate: 0.0018
# Epoch 132/400
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 800.4591 - val_loss: 678.1749 - learning_rate: 0.0018
# Epoch 133/400
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 811.3608 - val_loss: 665.6694 - learning_rate: 0.0018
# Epoch 134/400
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 800.0823 - val_loss: 662.9216 - learning_rate: 0.0018
# Epoch 135/400
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 809.2872 - val_loss: 668.0229 - learning_rate: 0.0017
# Epoch 136/400
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 797.2396 - val_loss: 671.2194 - learning_rate: 0.0017
# Epoch 137/400
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 810.1757 - val_loss: 664.7421 - learning_rate: 0.0017
# Epoch 138/400
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 797.8030 - val_loss: 666.6387 - learning_rate: 0.0017
# Epoch 139/400
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 791.4354 - val_loss: 670.0157 - learning_rate: 0.0017
# Epoch 140/400
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 790.7368 - val_loss: 671.6824 - learning_rate: 0.0017
# Epoch 141/400
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 818.2669 - val_loss: 668.5624 - learning_rate: 0.0016
# Epoch 142/400
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 816.9413 - val_loss: 661.5309 - learning_rate: 0.0016
# Epoch 143/400
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 798.8203 - val_loss: 661.5096 - learning_rate: 0.0016
# Epoch 144/400
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 795.6392 - val_loss: 659.1063 - learning_rate: 0.0016
# Epoch 145/400
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 786.0308 - val_loss: 671.2795 - learning_rate: 0.0016
# Epoch 146/400
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 816.9095 - val_loss: 658.8594 - learning_rate: 0.0016
# Epoch 147/400
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 804.3807 - val_loss: 667.3057 - learning_rate: 0.0016
# Epoch 148/400
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 792.4594 - val_loss: 669.4180 - learning_rate: 0.0015
# Epoch 149/400
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 797.0043 - val_loss: 658.9692 - learning_rate: 0.0015
# Epoch 150/400
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 795.9040 - val_loss: 657.8654 - learning_rate: 0.0015
# Epoch 151/400
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 781.5372 - val_loss: 658.0078 - learning_rate: 0.0015
# Epoch 152/400
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 781.7656 - val_loss: 679.4930 - learning_rate: 0.0015
# Epoch 153/400
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 794.4695 - val_loss: 659.9861 - learning_rate: 0.0015
# Epoch 154/400
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 796.9869 - val_loss: 658.5106 - learning_rate: 0.0014
# Epoch 155/400
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 809.9425 - val_loss: 658.2353 - learning_rate: 0.0014
# Epoch 156/400
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 809.5986 - val_loss: 659.2300 - learning_rate: 0.0014
# Epoch 157/400
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 793.6196 - val_loss: 656.7645 - learning_rate: 0.0014
# Epoch 158/400
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 772.5267 - val_loss: 660.8992 - learning_rate: 0.0014
# Epoch 159/400
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 791.7269 - val_loss: 655.8430 - learning_rate: 0.0014
# Epoch 160/400
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 798.9324 - val_loss: 657.1068 - learning_rate: 0.0014
# Epoch 161/400
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 813.6689 - val_loss: 663.0146 - learning_rate: 0.0013
# Epoch 162/400
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 782.5394 - val_loss: 658.0231 - learning_rate: 0.0013
# Epoch 163/400
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 807.5979 - val_loss: 660.7957 - learning_rate: 0.0013
# Epoch 164/400
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 797.3749 - val_loss: 659.5907 - learning_rate: 0.0013
# Epoch 165/400
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 789.4601 - val_loss: 653.8090 - learning_rate: 0.0013
# Epoch 166/400
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 786.7156 - val_loss: 656.4089 - learning_rate: 0.0013
# Epoch 167/400
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 794.1228 - val_loss: 657.1353 - learning_rate: 0.0013
# Epoch 168/400
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 795.3129 - val_loss: 662.6542 - learning_rate: 0.0013
# Epoch 169/400
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 785.5746 - val_loss: 654.2048 - learning_rate: 0.0012
# Epoch 170/400
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 795.4399 - val_loss: 663.1451 - learning_rate: 0.0012
# Epoch 171/400
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 796.6732 - val_loss: 654.3282 - learning_rate: 0.0012
# Epoch 172/400
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 775.8788 - val_loss: 660.9177 - learning_rate: 0.0012
# Epoch 173/400
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 785.6854 - val_loss: 672.8721 - learning_rate: 0.0012
# Epoch 174/400
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 799.2317 - val_loss: 667.9673 - learning_rate: 0.0012
# Epoch 175/400
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 797.1032 - val_loss: 654.4301 - learning_rate: 0.0012
# Epoch 176/400
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 805.3349 - val_loss: 662.0201 - learning_rate: 0.0012
# Epoch 177/400
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 805.0660 - val_loss: 659.3549 - learning_rate: 0.0011
# Epoch 178/400
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 788.9730 - val_loss: 660.4722 - learning_rate: 0.0011
# Epoch 179/400
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 795.3315 - val_loss: 664.9741 - learning_rate: 0.0011
# Epoch 180/400
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 794.3055 - val_loss: 673.8365 - learning_rate: 0.0011
# Epoch 181/400
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 791.5364 - val_loss: 658.5853 - learning_rate: 0.0011
# Epoch 182/400
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 805.7531 - val_loss: 658.1009 - learning_rate: 0.0011
# Epoch 183/400
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 794.6281 - val_loss: 664.8536 - learning_rate: 0.0011
# Epoch 184/400
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 784.5169 - val_loss: 664.9429 - learning_rate: 0.0011
# Epoch 185/400
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 781.8851 - val_loss: 652.1925 - learning_rate: 0.0011
# Epoch 186/400
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 787.9744 - val_loss: 653.9265 - learning_rate: 0.0011
# Epoch 187/400
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 790.4482 - val_loss: 688.4185 - learning_rate: 0.0010
# Epoch 188/400
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 803.3950 - val_loss: 654.5521 - learning_rate: 0.0010
# Epoch 189/400
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 771.1849 - val_loss: 663.2332 - learning_rate: 0.0010
# Epoch 190/400
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 775.9828 - val_loss: 681.4046 - learning_rate: 0.0010
# Epoch 191/400
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 788.7745 - val_loss: 662.9988 - learning_rate: 9.9944e-04
# Epoch 192/400
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 797.6243 - val_loss: 665.9357 - learning_rate: 9.8949e-04
# Epoch 193/400
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 800.9075 - val_loss: 671.7050 - learning_rate: 9.7965e-04
# Epoch 194/400
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 813.4092 - val_loss: 657.4616 - learning_rate: 9.6990e-04
# Epoch 195/400
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 794.9918 - val_loss: 656.4096 - learning_rate: 9.6025e-04
# Epoch 196/400
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 796.7888 - val_loss: 677.2056 - learning_rate: 9.5070e-04
# Epoch 197/400
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 769.7497 - val_loss: 655.0434 - learning_rate: 9.4124e-04
# Epoch 198/400
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 801.7715 - val_loss: 652.0175 - learning_rate: 9.3187e-04
# Epoch 199/400
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 784.0812 - val_loss: 668.4189 - learning_rate: 9.2260e-04
# Epoch 200/400
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 810.0371 - val_loss: 651.4216 - learning_rate: 9.1342e-04
# Epoch 201/400
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 784.2974 - val_loss: 662.5483 - learning_rate: 9.0433e-04
# Epoch 202/400
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 796.7210 - val_loss: 666.8311 - learning_rate: 8.9533e-04
# Epoch 203/400
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 785.4546 - val_loss: 671.5292 - learning_rate: 8.8642e-04
# Epoch 204/400
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 785.3957 - val_loss: 665.5457 - learning_rate: 8.7760e-04
# Epoch 205/400
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 775.5470 - val_loss: 672.1975 - learning_rate: 8.6887e-04
# Epoch 206/400
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 807.3042 - val_loss: 662.0033 - learning_rate: 8.6023e-04
# Epoch 207/400
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 808.5064 - val_loss: 651.8323 - learning_rate: 8.5167e-04
# Epoch 208/400
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 795.8618 - val_loss: 656.2934 - learning_rate: 8.4319e-04
# Epoch 209/400
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 785.3595 - val_loss: 661.2254 - learning_rate: 8.3480e-04
# Epoch 210/400
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 785.8530 - val_loss: 676.9383 - learning_rate: 8.2650e-04
# Epoch 211/400
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 804.4685 - val_loss: 686.0752 - learning_rate: 8.1827e-04
# Epoch 212/400
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 793.3444 - val_loss: 655.7671 - learning_rate: 8.1013e-04
# Epoch 213/400
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 791.9984 - val_loss: 662.8038 - learning_rate: 8.0207e-04
# Epoch 214/400
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 789.4297 - val_loss: 661.1994 - learning_rate: 7.9409e-04
# Epoch 215/400
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 787.0828 - val_loss: 654.8044 - learning_rate: 7.8619e-04
# Epoch 216/400
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 770.7682 - val_loss: 651.0154 - learning_rate: 7.7836e-04
# Epoch 217/400
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 773.4641 - val_loss: 653.1918 - learning_rate: 7.7062e-04
# Epoch 218/400
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 786.9273 - val_loss: 664.6350 - learning_rate: 7.6295e-04
# Epoch 219/400
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 790.1652 - val_loss: 651.0500 - learning_rate: 7.5536e-04
# Epoch 220/400
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 776.9886 - val_loss: 668.2184 - learning_rate: 7.4784e-04
# Epoch 221/400
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 799.9911 - val_loss: 680.2204 - learning_rate: 7.4040e-04
# Epoch 222/400
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 787.0007 - val_loss: 679.2836 - learning_rate: 7.3304e-04
# Epoch 223/400
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 779.7809 - val_loss: 678.8365 - learning_rate: 7.2574e-04
# Epoch 224/400
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 797.2718 - val_loss: 668.6718 - learning_rate: 7.1852e-04
# Epoch 225/400
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 782.4893 - val_loss: 666.0135 - learning_rate: 7.1137e-04
# Epoch 226/400
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 775.5754 - val_loss: 646.1694 - learning_rate: 7.0429e-04
# Epoch 227/400
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 768.1087 - val_loss: 687.2482 - learning_rate: 6.9729e-04
# Epoch 228/400
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 781.9352 - val_loss: 660.3873 - learning_rate: 6.9035e-04
# Epoch 229/400
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 786.0196 - val_loss: 662.8192 - learning_rate: 6.8348e-04
# Epoch 230/400
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 777.0189 - val_loss: 660.7944 - learning_rate: 6.7668e-04
# Epoch 231/400
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 773.5786 - val_loss: 660.7513 - learning_rate: 6.6994e-04
# Epoch 232/400
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 781.8671 - val_loss: 668.5799 - learning_rate: 6.6328e-04
# Epoch 233/400
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 783.5770 - val_loss: 661.9365 - learning_rate: 6.5668e-04
# Epoch 234/400
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 786.7023 - val_loss: 659.2880 - learning_rate: 6.5014e-04
# Epoch 235/400
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 768.7634 - val_loss: 675.7409 - learning_rate: 6.4368e-04
# Epoch 236/400
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 789.7773 - val_loss: 650.1130 - learning_rate: 6.3727e-04
# Epoch 237/400
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 780.1265 - val_loss: 658.1046 - learning_rate: 6.3093e-04
# Epoch 238/400
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 802.5703 - val_loss: 661.8408 - learning_rate: 6.2465e-04
# Epoch 239/400
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 797.3179 - val_loss: 653.9658 - learning_rate: 6.1844e-04
# Epoch 240/400
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 794.9376 - val_loss: 673.0859 - learning_rate: 6.1228e-04
# Epoch 241/400
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 805.6310 - val_loss: 659.1016 - learning_rate: 6.0619e-04
# Epoch 242/400
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 769.1924 - val_loss: 654.7460 - learning_rate: 6.0016e-04
# Epoch 243/400
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 786.8731 - val_loss: 655.0044 - learning_rate: 5.9419e-04
# Epoch 244/400
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 786.2266 - val_loss: 668.1645 - learning_rate: 5.8828e-04
# Epoch 245/400
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 788.7772 - val_loss: 652.1033 - learning_rate: 5.8242e-04
# Epoch 246/400
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 773.4979 - val_loss: 655.6881 - learning_rate: 5.7663e-04
# Epoch 246: early stopping
# Restoring model weights from the end of the best epoch: 226.

# %%
import matplotlib.pyplot as plt

def plot_loss(history):
    plt.plot(history.history['loss'], label='loss')
    plt.plot(history.history['val_loss'], label='val_loss')
    plt.ylim([0, 1200])
    plt.xlabel('Epoch')
    plt.ylabel('Error [Price]')
    plt.legend()
    plt.grid(True)

plot_loss(history)

# %%
# test model
dnn_model.evaluate(X_test, y_test, verbose=1)
# Out:
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 751.2579
# 756.9004516601562

# %% [markdown]
# The base model performs worse than voting regression. Let's check the complex model.

# %%
# compile complex model
dnn_model = build_and_compile_complex_model()

# %%
dnn_model.summary()
# Out:
# Model: "sequential_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ normalization_3 (Normalization)      │ (None, 50)                  │             101 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_9 (Dense)                      │ (None, 64)                  │           3,264 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_3 (Dropout)                  │ (None, 64)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_10 (Dense)                     │ (None, 8)                   │             520 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_11 (Dense)                     │ (None, 8)                   │              72 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_12 (Dense)                     │ (None, 1)                   │               9 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 3,966 (15.50 KB)
#  Trainable params: 3,865 (15.10 KB)
#  Non-trainable params: 101 (408.00 B)

# %%
# train complex model
history = dnn_model.fit(
    X_train,
    y_train,
    validation_data=(X_val, y_val),
    callbacks = [scheduler_c, early_stopping],
    verbose=1, epochs=50)
# Out:
# Epoch 1/50
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 2908.6023 - val_loss: 2184.7102 - learning_rate: 0.0050
# Epoch 2/50
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 2178.3638 - val_loss: 2030.0300 - learning_rate: 0.0050
# Epoch 3/50
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 1899.8988 - val_loss: 1327.4650 - learning_rate: 0.0050
# Epoch 4/50
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1379.3242 - val_loss: 1251.5814 - learning_rate: 0.0050
# Epoch 5/50
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1300.8312 - val_loss: 1193.2589 - learning_rate: 0.0050
# Epoch 6/50
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1258.2791 - val_loss: 1140.5752 - learning_rate: 0.0050
# Epoch 7/50
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1208.1013 - val_loss: 1091.0581 - learning_rate: 0.0050
# Epoch 8/50
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1161.3049 - val_loss: 1047.8558 - learning_rate: 0.0050
# Epoch 9/50
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 1133.7509 - val_loss: 1030.0936 - learning_rate: 0.0050
# Epoch 10/50
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1120.2837 - val_loss: 985.8345 - learning_rate: 0.0050
# Epoch 11/50
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1093.2769 - val_loss: 938.4374 - learning_rate: 0.0050
# Epoch 12/50
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 1040.2379 - val_loss: 904.4766 - learning_rate: 0.0050
# Epoch 13/50
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1018.5950 - val_loss: 883.3381 - learning_rate: 0.0050
# Epoch 14/50
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1011.4178 - val_loss: 876.8552 - learning_rate: 0.0050
# Epoch 15/50
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 991.9661 - val_loss: 854.4061 - learning_rate: 0.0050
# Epoch 16/50
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 993.9272 - val_loss: 831.3094 - learning_rate: 0.0050
# Epoch 17/50
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 972.5728 - val_loss: 826.2980 - learning_rate: 0.0050
# Epoch 18/50
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 974.2968 - val_loss: 835.1877 - learning_rate: 0.0050
# Epoch 19/50
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 969.1251 - val_loss: 807.8958 - learning_rate: 0.0050
# Epoch 20/50
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 955.8726 - val_loss: 800.2145 - learning_rate: 0.0050
# Epoch 21/50
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 977.4925 - val_loss: 797.2272 - learning_rate: 0.0050
# Epoch 22/50
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 952.2123 - val_loss: 824.4278 - learning_rate: 0.0050
# Epoch 23/50
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 944.8600 - val_loss: 790.6201 - learning_rate: 0.0050
# Epoch 24/50
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 944.3426 - val_loss: 785.3289 - learning_rate: 0.0050
# Epoch 25/50
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 934.5722 - val_loss: 781.9881 - learning_rate: 0.0050
# Epoch 26/50
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 959.9595 - val_loss: 780.5989 - learning_rate: 0.0050
# Epoch 27/50
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 954.5543 - val_loss: 775.9333 - learning_rate: 0.0050
# Epoch 28/50
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 925.9220 - val_loss: 823.1506 - learning_rate: 0.0050
# Epoch 29/50
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 919.5729 - val_loss: 777.6094 - learning_rate: 0.0050
# Epoch 30/50
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 907.0037 - val_loss: 765.0000 - learning_rate: 0.0050
# Epoch 31/50
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 913.5155 - val_loss: 761.0809 - learning_rate: 0.0050
# Epoch 32/50
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 925.0152 - val_loss: 763.0903 - learning_rate: 0.0049
# Epoch 33/50
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 919.2538 - val_loss: 770.5486 - learning_rate: 0.0049
# Epoch 34/50
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 907.7839 - val_loss: 754.4269 - learning_rate: 0.0048
# Epoch 35/50
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 919.5269 - val_loss: 752.5264 - learning_rate: 0.0048
# Epoch 36/50
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 897.6763 - val_loss: 757.5699 - learning_rate: 0.0047
# Epoch 37/50
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 911.1133 - val_loss: 760.2742 - learning_rate: 0.0047
# Epoch 38/50
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 917.4745 - val_loss: 777.1622 - learning_rate: 0.0046
# Epoch 39/50
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 911.9076 - val_loss: 763.4133 - learning_rate: 0.0046
# Epoch 40/50
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 892.8040 - val_loss: 747.1257 - learning_rate: 0.0045
# Epoch 41/50
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 922.2440 - val_loss: 816.2512 - learning_rate: 0.0045
# Epoch 42/50
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 901.7004 - val_loss: 742.6039 - learning_rate: 0.0044
# Epoch 43/50
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 903.2443 - val_loss: 765.2909 - learning_rate: 0.0044
# Epoch 44/50
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 882.5458 - val_loss: 733.9332 - learning_rate: 0.0043
# Epoch 45/50
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 873.3246 - val_loss: 742.7930 - learning_rate: 0.0043
# Epoch 46/50
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 866.8422 - val_loss: 725.0970 - learning_rate: 0.0043
# Epoch 47/50
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 858.8679 - val_loss: 731.9988 - learning_rate: 0.0042
# Epoch 48/50
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 886.1251 - val_loss: 723.2646 - learning_rate: 0.0042
# Epoch 49/50
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 875.8789 - val_loss: 725.9767 - learning_rate: 0.0041
# Epoch 50/50
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 874.6906 - val_loss: 720.0581 - learning_rate: 0.0041
# Restoring model weights from the end of the best epoch: 50.

# %%
plot_loss(history)

# %%
# test complex model
dnn_model.evaluate(X_test, y_test, verbose=1)
# Out:
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 799.7224
# 801.1624755859375

# %% [markdown]
# This result is slightly worse than the base model. Probably, our task is not so complex to solve with deep neural networks. So, we choose voting regressor performance as best for this dataset among all explored algorithms.

# %% [markdown]
# # **Feature Selection**
# Feature selection hurts the performance of this task. However, it is always best to present all the methods applied through the assignment. Hence, we are representing it also. We used f_regression and RandomForestRegressor.modelimportances to check feature importance. We decided on k=15, but you can change and see the results for different k values.

# %%
from sklearn.feature_selection import SelectKBest, f_regression
#Select top 25 features based on f-regression
selector = SelectKBest(f_regression, k =25)
X = new_df[selected_features].to_numpy()
y = df[label_col].to_numpy().ravel()
selector.fit(X, y)
cols = new_df[selected_features].columns[selector.get_support()].to_list()
cols
# Out:
# ['intel pentium quad-core ',
#  'intel celeron ',
#  'windows 8.1 home 64-bit',
#  'amd a6',
#  'intel celeron dual-core',
#  'emmc',
#  'intel pentium dual-core',
#  'other',
#  'ddr3l',
#  'no system',
#  'windows 10 professional',
#  'modem 4g (lte)',
#  'ssd + hdd',
#  'intel core i3',
#  'ddr3',
#  'wi-fi',
#  'illuminated keyboard',
#  'lan 10/100 mbps',
#  'numeric keyboard',
#  'RAM size',
#  'intel wireless display (widi)',
#  'modem 3g (wwan)',
#  'nfc (near field communication)',
#  'drive memory size (GB)',
#  'SD card reader']

# %%
X_train, X_val, X_test = train_df[cols].to_numpy(), val_df[cols].to_numpy(), test_df[cols].to_numpy()
y_train, y_val, y_test = df.loc[train_indeces][label_col].to_numpy().ravel(), df.loc[val_indeces][label_col].to_numpy().ravel(), df.loc[test_indeces][label_col].to_numpy().ravel()

# %%
regression('RandomForest', regressors['RandomForest'])
# Out:
# RandomForest : 736.9071175455939

# %%
X = new_df[selected_features].values
X_train, X_val, X_test = train_df[selected_features].to_numpy(), val_df[selected_features].to_numpy(), test_df[selected_features].to_numpy()
y_train, y_val, y_test = df.loc[train_indeces][label_col].to_numpy().ravel(), df.loc[val_indeces][label_col].to_numpy().ravel(), df.loc[test_indeces][label_col].to_numpy().ravel()
model = RandomForestRegressor(random_state=42)
# fit the model
model.fit(X_train, y_train)
# get importance
importance = model.feature_importances_
# summarize feature importance
for i,v in enumerate(importance):
    print(f"Feature: {selected_features[i]} , Score: {v}")
# plot feature importance
plt.figure(figsize=(12, 9)) # width and height in inches
plt.bar(selected_features, importance)
plt.xticks(rotation = 90)
plt.tight_layout()
plt.show()
# Out:
# Feature: windows 8.1 professional 32-bit , Score: 4.810689624538485e-06
# Feature: windows 7 home 64-bit , Score: 0.0
# Feature: intel celeron m , Score: 7.3554278709924e-05
# Feature: windows 7 professional 32-bit , Score: 0.0
# Feature: intel core m , Score: 0.0002266984700607659
# Feature: windows 8.1 home 32-bit , Score: 8.600625225448644e-05
# Feature: amd a4 , Score: 0.00045751140898403226
# Feature: amd e1 , Score: 0.0002670158662038192
# Feature: amd a10 , Score: 0.0006366782404907569
# Feature: amd a12 , Score: 0.00023839630878936258
# Feature: hybrid , Score: 0.0004379279547672437
# Feature: wi-fi 802.11 a/b/g/n , Score: 0.00037786906716814986
# Feature: amd a8 , Score: 0.0003626115253238574
# Feature: windows 8.1 professional 64-bit , Score: 0.0006198258529816793
# Feature: intel celeron quad core  , Score: 0.00014862929923655828
# Feature: intel pentium quad-core  , Score: 0.0007590677752839066
# Feature: wi-fi 802.11 b/g/n , Score: 0.0003618387431345358
# Feature: wi-fi 802.11 a/b/g/n/ac , Score: 0.0013913043430696947
# Feature: wi-fi 802.11 b/g/n/ac , Score: 0.0006405118913359903
# Feature: intel celeron  , Score: 0.0004815375907977889
# Feature: windows 8.1 home 64-bit , Score: 0.0010849679208070103
# Feature: amd a6 , Score: 0.0028152186619363325
# Feature: intel celeron dual-core , Score: 0.001799805631315259
# Feature: emmc , Score: 5.9301815143748575e-05
# Feature: windows 7 professional 64-bit , Score: 0.0015885048976485208
# Feature: intel pentium dual-core , Score: 0.0013072499514547471
# Feature: other , Score: 0.004105070922731269
# Feature: ddr3l , Score: 0.006417779171409947
# Feature: no system , Score: 0.020767244426574048
# Feature: windows 10 professional , Score: 0.030748450246545687
# Feature: modem 4g (lte) , Score: 0.005264655414849057
# Feature: ssd + hdd , Score: 0.004165494019411715
# Feature: gps , Score: 0.0025631665254878078
# Feature: intel core i5 , Score: 0.034276719102856554
# Feature: intel core i3 , Score: 0.01711346108478545
# Feature: ddr3 , Score: 0.025732171579442242
# Feature: wi-fi , Score: 0.011952777168380592
# Feature: illuminated keyboard , Score: 0.417824781394016
# Feature: lan 10/100 mbps , Score: 0.02531278505294521
# Feature: numeric keyboard , Score: 0.022328606139788612
# Feature: RAM size , Score: 0.11051811519972408
# Feature: ssd , Score: 0.01681845162491978
# Feature: intel wireless display (widi) , Score: 0.00916571746870353
# Feature: modem 3g (wwan) , Score: 0.004881644284383514
# Feature: nfc (near field communication) , Score: 0.004411005099408875
# Feature: lan 10/100/1000 mbps , Score: 0.009603874452862558
# Feature: drive memory size (GB) , Score: 0.07035469675251318
# Feature: SD card reader , Score: 0.12071096923748684
# Feature: speakers , Score: 0.0022021907942647383
# Feature: microphone , Score: 0.006533328399986001

# %%
feats_w_highest_importance = np.array(selected_features)[importance > 0.02].tolist()
feats_w_highest_importance
# Out:
# ['no system',
#  'windows 10 professional',
#  'intel core i5',
#  'ddr3',
#  'illuminated keyboard',
#  'lan 10/100 mbps',
#  'numeric keyboard',
#  'RAM size',
#  'drive memory size (GB)',
#  'SD card reader']

# %%
regression('RandomForest', regressors['RandomForest'])
# Out:
# RandomForest : 604.2753477464071

# %% [markdown]
# Still, the complete feature set provides better results compared to features with the highest importance.
